# %% [markdown]
# #### imports

# %%
from google.colab import drive
drive.mount('/content/drive')
project_path = '/content/drive/MyDrive/lewagon-deepdive/'
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Load a dataset

# %%
path_to_dataset = '/content/drive/MyDrive/lewagon-deepdive/raw_data/watkins_sound_list_extended.csv'
dataset = pd.read_csv(path_to_dataset)
dataset = dataset.rename(columns={"species_name_x": "species_name"})
dataset
# Out:
#       family_code  family_name species_code           species_name  \
# 0              BD  Delphinidae        BD15F     Stenella frontalis
# 1              BD  Delphinidae        BD15F     Stenella frontalis
# 2              BD  Delphinidae        BD15F     Stenella frontalis
# 3              BD  Delphinidae        BD15F     Stenella frontalis
# 4              BD  Delphinidae        BD15F     Stenella frontalis
# ...           ...          ...          ...                    ...
# 15560          BD  Delphinidae         BD6A  Lagenorhynchus acutus
# 15561          BD  Delphinidae         BD6A  Lagenorhynchus acutus
# 15562          BD  Delphinidae         BD6A  Lagenorhynchus acutus
# 15563          BD  Delphinidae         BD6A  Lagenorhynchus acutus
# 15564          BD  Delphinidae         BD6A  Lagenorhynchus acutus
#
#                     common_name            filename  duration  \
# 0      Atlantic Spotted Dolphin  BD15F_61025001.wav  3.527995
# ...

# %%
dataset.shape
# Out:
# (15565, 11)

# %% [markdown]
# # Check balance of categories

# %% [markdown]
# ## Count of categories

# %%
plt.figure(figsize=(10,10))
sns.barplot(x=dataset['species_code'].value_counts(), y=dataset['species_code'].unique());

# %% [markdown]
# ## Duration of categories

# %%
df_duration = dataset.groupby(['species_code']).sum()
df_duration.sort_values(by='duration', ascending=False, inplace = True)


plt.figure(figsize=(10,10))
sns.barplot(x=df_duration.duration, y=df_duration.index);
