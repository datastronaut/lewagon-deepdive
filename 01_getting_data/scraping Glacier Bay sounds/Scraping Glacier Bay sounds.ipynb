# %% [markdown]
# Scraping sounds recorded here: https://www.nps.gov/glba/learn/nature/soundclips.htm

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time
import random
from tqdm import tqdm

# %%
url = 'https://www.nps.gov/glba/learn/nature/soundclips.htm'
response = requests.get(url)
soup = BeautifulSoup(response.content, "html.parser")

# %%
titles = [sub_soup.string for sub_soup in soup.find(id='cs_idCell2x1x1').find_all('h3')]
titles
# Out:
# [None,
#  'Glacier Bay humpback whale song November 2020',
#  '2020 humpback whale slaps and vocals with harbor seal',
#  'humpback whale feeding call',
#  'Humpback whale vocals and loud snaps',
#  'Humpback whale bubble-feeding and vocalizing',
#  'Outboard Engine Whine and Humpback Whale Song',
#  'Glacier Bay 60-second clip humpback whale song November 2020',
#  None,
#  'Resident Killer Whale Vocalizations',
#  'Offshore Killer Whale Vocalizations',
#  'Transient Killer Whale Vocalizations',
#  'Killer Whale Echolocation Clicks',
#  None,
#  'Harbor Seal Vocalization - August 7, 2020',
#  'Other Animal Sounds',
#  'Seabirds Calling at Sea Surface',
#  'Seabirds Diving at Sea Surface',
#  'Unknown Animal Knock on Hydrophone - "Knockfish"',
#  'Vessel Sounds',
#  'Cruise Ship Underwater Recording',
#  'State Ferry Hydrophone Recording',
#  'Freighter Hydrophone Recording',
#  'Small Diesel Engine Hydrophone Recording',
#  'Outboard Engine Whine and Acceleration',
#  'Outboard Engine (60hp) at 10 Knots',
#  'Outboard Engine (60hp) at 20 Knots',
#  'Propeller Whine Hydrophone Recording',
#  'Ambient Noise',
#  'Heavy Rain on Sea Surface',
#  'Light Rain on Sea Surface',
#  'Snowfall on Sea Surface',
#  'Light Wind at the Sea Surface - Underwater Recording',
#  'Moderate Wind on the Sea Surface - Underwater Recording',
#  'Wind and Ship Noise on Underwater Hydrophone']

# %%
#removing None
titles = [item for item in titles if item]
titles
# Out:
# ['Glacier Bay humpback whale song November 2020',
#  '2020 humpback whale slaps and vocals with harbor seal',
#  'humpback whale feeding call',
#  'Humpback whale vocals and loud snaps',
#  'Humpback whale bubble-feeding and vocalizing',
#  'Outboard Engine Whine and Humpback Whale Song',
#  'Glacier Bay 60-second clip humpback whale song November 2020',
#  'Resident Killer Whale Vocalizations',
#  'Offshore Killer Whale Vocalizations',
#  'Transient Killer Whale Vocalizations',
#  'Killer Whale Echolocation Clicks',
#  'Harbor Seal Vocalization - August 7, 2020',
#  'Other Animal Sounds',
#  'Seabirds Calling at Sea Surface',
#  'Seabirds Diving at Sea Surface',
#  'Unknown Animal Knock on Hydrophone - "Knockfish"',
#  'Vessel Sounds',
#  'Cruise Ship Underwater Recording',
#  'State Ferry Hydrophone Recording',
#  'Freighter Hydrophone Recording',
#  'Small Diesel Engine Hydrophone Recording',
#  'Outboard Engine Whine and Acceleration',
#  'Outboard Engine (60hp) at 10 Knots',
#  'Outboard Engine (60hp) at 20 Knots',
#  'Propeller Whine Hydrophone Recording',
#  'Ambient Noise',
#  'Heavy Rain on Sea Surface',
#  'Light Rain on Sea Surface',
#  'Snowfall on Sea Surface',
#  'Light Wind at the Sea Surface - Underwater Recording',
#  'Moderate Wind on the Sea Surface - Underwater Recording',
#  'Wind and Ship Noise on Underwater Hydrophone']

# %%
# removing 'Vessel Sounds', 'Ambient Noise' and 'Other Animal Sounds'
titles.remove('Vessel Sounds')
titles.remove('Ambient Noise')
titles.remove('Other Animal Sounds')

# %%
titles
# Out:
# ['Glacier Bay humpback whale song November 2020',
#  '2020 humpback whale slaps and vocals with harbor seal',
#  'humpback whale feeding call',
#  'Humpback whale vocals and loud snaps',
#  'Humpback whale bubble-feeding and vocalizing',
#  'Outboard Engine Whine and Humpback Whale Song',
#  'Glacier Bay 60-second clip humpback whale song November 2020',
#  'Resident Killer Whale Vocalizations',
#  'Offshore Killer Whale Vocalizations',
#  'Transient Killer Whale Vocalizations',
#  'Killer Whale Echolocation Clicks',
#  'Harbor Seal Vocalization - August 7, 2020',
#  'Seabirds Calling at Sea Surface',
#  'Seabirds Diving at Sea Surface',
#  'Unknown Animal Knock on Hydrophone - "Knockfish"',
#  'Cruise Ship Underwater Recording',
#  'State Ferry Hydrophone Recording',
#  'Freighter Hydrophone Recording',
#  'Small Diesel Engine Hydrophone Recording',
#  'Outboard Engine Whine and Acceleration',
#  'Outboard Engine (60hp) at 10 Knots',
#  'Outboard Engine (60hp) at 20 Knots',
#  'Propeller Whine Hydrophone Recording',
#  'Heavy Rain on Sea Surface',
#  'Light Rain on Sea Surface',
#  'Snowfall on Sea Surface',
#  'Light Wind at the Sea Surface - Underwater Recording',
#  'Moderate Wind on the Sea Surface - Underwater Recording',
#  'Wind and Ship Noise on Underwater Hydrophone']

# %%
download_links = [sub_soup.find("source")['src'] for sub_soup in soup.find_all(class_='video-js')[1:]]
download_links
# Out:
# ['https://www.nps.gov/nps-audiovideo/audiovideo/65381587-aedd-449b-8f4c-7f8bb553be4f.mp3',
#  'https://www.nps.gov/nps-audiovideo/audiovideo/b8fc6195-c16f-4508-ba6a-9cb527a85cb2.mp3',
#  'https://www.nps.gov/nps-audiovideo/audiovideo/cde82ded-68b8-4c67-b6c3-9ab190908357.mp3',
#  'https://www.nps.gov/nps-audiovideo/audiovideo/5635e3d6-1b3a-4c6b-8f90-28fdfbc4155c.mp3',
#  'https://www.nps.gov/nps-audiovideo/audiovideo/f7af47fb-4601-4fa3-9274-41be41b93276.mp3',
#  'https://www.nps.gov/nps-audiovideo/audiovideo/c1cda635-32ce-4917-ab9b-b09b12dacc5c.mp3',
#  'https://www.nps.gov/nps-audiovideo/audiovideo/4e34e6c7-5267-4c0b-8ff9-bf506086aa56.mp3',
#  'https://www.nps.gov/nps-audiovideo/audiovideo/e60488c2-30fb-414b-bc9f-ee16f886a897.mp3',
#  'https://www.nps.gov/nps-audiovideo/audiovideo/76d2ae6f-616f-4ef1-91a8-d797cbf7cd36.mp3',
#  'https://www.nps.gov/nps-audiovideo/audiovideo/d708efda-0bef-4399-b256-b5346836405c.mp3',
#  'https://www.nps.gov/nps-audiovideo/audiovideo/2832079a-0115-4b94-b895-185317774abd.mp3',
#  'https://www.nps.gov/nps-audiovideo/audiovideo/c014d5aa-ed06-4d04-9f12-517fd2041065.mp3',
#  'https://www.nps.gov/nps-audiovideo/audiovideo/5b5fdb91-4101-41ac-83dc-630d939fcf81.mp3',
#  'https://www.nps.gov/nps-audiovideo/audiovideo/fa0f03c7-1cb5-44cd-9ec6-5d98de27f8c7.mp3',
#  'https://www.nps.gov/nps-audiovideo/audiovideo/8154b44c-3748-4846-94de-3e420903e74f.mp3',
#  'https://www.nps.gov/nps-audiovideo/audiovideo/1cc5583b-fe72-4cb2-b64c-563bd87ad91b.mp3',
#  'https://www.nps.gov/nps-audiovideo/audiovideo/9ff56b54-6739-4440-a28e-26a251bc9f78.mp3',
#  'https://www.nps.gov/nps-audiovideo/audiovideo/7dd6d0fe-831f-4a11-9837-1b4f629d429b.mp3',
#  'https://www.nps.gov/nps-audiovideo/audiovideo/cb678cb6-5627-4544-9fbb-c8e3884f0827.mp3',
#  'https://www.nps.gov/nps-audiovideo/audiovideo/d118c015-9bf4-426e-98f3-2d71b5150d19.mp3',
#  'https://www.nps.gov/nps-audiovideo/audiovideo/705da20f-b986-4e49-ae58-39f9f286e9ad.mp3',
#  'https://www.nps.gov/nps-audiovideo/audiovideo/39f7562b-1d7a-4fe4-a969-6be98e7d4886.mp3',
#  'https://www.nps.gov/nps-audiovideo/audiovideo/df664e4a-27e9-493f-85ad-9f5e4968b282.mp3',
#  'https://www.nps.gov/nps-audiovideo/audiovideo/30679527-fd7a-4cad-8c7d-cb1bcc07604d.mp3',
#  'https://www.nps.gov/nps-audiovideo/audiovideo/f9652ad2-39f5-41b4-a8e4-89171a864f03.mp3',
#  'https://www.nps.gov/nps-audiovideo/audiovideo/2b68b3a9-7c0d-4452-bbe5-cc99b5d4fb61.mp3',
#  'https://www.nps.gov/nps-audiovideo/audiovideo/0f9867d8-fcf7-40d1-b846-3f7fb8100eb7.mp3',
#  'https://www.nps.gov/nps-audiovideo/audiovideo/2f574049-3325-446c-a8ac-2e5b31e9e32f.mp3',
#  'https://www.nps.gov/nps-audiovideo/audiovideo/c80d9ad4-48d1-46c6-a8d6-ede260f4f066.mp3']

# %%
data = {'title': titles, 'download_link': download_links}
df = pd.DataFrame.from_dict(data)
df
# Out:
#                                                 title  \
# 0       Glacier Bay humpback whale song November 2020
# 1   2020 humpback whale slaps and vocals with harb...
# 2                         humpback whale feeding call
# 3                Humpback whale vocals and loud snaps
# 4        Humpback whale bubble-feeding and vocalizing
# 5       Outboard Engine Whine and Humpback Whale Song
# 6   Glacier Bay 60-second clip humpback whale song...
# 7                 Resident Killer Whale Vocalizations
# 8                 Offshore Killer Whale Vocalizations
# 9                Transient Killer Whale Vocalizations
# 10                   Killer Whale Echolocation Clicks
# 11          Harbor Seal Vocalization - August 7, 2020
# 12                    Seabirds Calling at Sea Surface
# 13                     Seabirds Diving at Sea Surface
# 14   Unknown Animal Knock on Hydrophone - "Knockfish"
# 15                   Cruise Ship Underwater Recording
# 16                   State Ferry Hydrophone Recording
# 17                     Freighter Hydrophone Recording
# 18           Small Diesel Engine Hydrophone Recording
# 19             Outboard Engine Whine and Acceleration
# 20                 Outboard Engine (60hp) at 10 Knots
# 21                 Outboard Engine (60hp) at 20 Knots
# 22               Propeller Whine Hydrophone Recording
# 23                          Heavy Rain on Sea Surface
# 24                          Light Rain on Sea Surface
# 25                            Snowfall on Sea Surface
# 26  Light Wind at the Sea Surface - Underwater Rec...
# 27  Moderate Wind on the Sea Surface - Underwater ...
# 28       Wind and Ship Noise on Underwater Hydrophone
#
#                                         download_link
# 0   https://www.nps.gov/nps-audiovideo/audiovideo/...
# 1   https://www.nps.gov/nps-audiovideo/audiovideo/...
# 2   https://www.nps.gov/nps-audiovideo/audiovideo/...
# 3   https://www.nps.gov/nps-audiovideo/audiovideo/...
# 4   https://www.nps.gov/nps-audiovideo/audiovideo/...
# 5   https://www.nps.gov/nps-audiovideo/audiovideo/...
# 6   https://www.nps.gov/nps-audiovideo/audiovideo/...
# 7   https://www.nps.gov/nps-audiovideo/audiovideo/...
# 8   https://www.nps.gov/nps-audiovideo/audiovideo/...
# 9   https://www.nps.gov/nps-audiovideo/audiovideo/...
# 10  https://www.nps.gov/nps-audiovideo/audiovideo/...
# 11  https://www.nps.gov/nps-audiovideo/audiovideo/...
# 12  https://www.nps.gov/nps-audiovideo/audiovideo/...
# 13  https://www.nps.gov/nps-audiovideo/audiovideo/...
# 14  https://www.nps.gov/nps-audiovideo/audiovideo/...
# 15  https://www.nps.gov/nps-audiovideo/audiovideo/...
# 16  https://www.nps.gov/nps-audiovideo/audiovideo/...
# 17  https://www.nps.gov/nps-audiovideo/audiovideo/...
# 18  https://www.nps.gov/nps-audiovideo/audiovideo/...
# 19  https://www.nps.gov/nps-audiovideo/audiovideo/...
# 20  https://www.nps.gov/nps-audiovideo/audiovideo/...
# 21  https://www.nps.gov/nps-audiovideo/audiovideo/...
# 22  https://www.nps.gov/nps-audiovideo/audiovideo/...
# 23  https://www.nps.gov/nps-audiovideo/audiovideo/...
# 24  https://www.nps.gov/nps-audiovideo/audiovideo/...
# 25  https://www.nps.gov/nps-audiovideo/audiovideo/...
# 26  https://www.nps.gov/nps-audiovideo/audiovideo/...
# 27  https://www.nps.gov/nps-audiovideo/audiovideo/...
# 28  https://www.nps.gov/nps-audiovideo/audiovideo/...

# %%
# replacing all ',' by ' -' in order not to mess up with csv conversion
df.replace(',', ' -', inplace=True, regex=True)
df
# Out:
#                                                 title  \
# 0       Glacier Bay humpback whale song November 2020
# 1   2020 humpback whale slaps and vocals with harb...
# 2                         humpback whale feeding call
# 3                Humpback whale vocals and loud snaps
# 4        Humpback whale bubble-feeding and vocalizing
# 5       Outboard Engine Whine and Humpback Whale Song
# 6   Glacier Bay 60-second clip humpback whale song...
# 7                 Resident Killer Whale Vocalizations
# 8                 Offshore Killer Whale Vocalizations
# 9                Transient Killer Whale Vocalizations
# 10                   Killer Whale Echolocation Clicks
# 11         Harbor Seal Vocalization - August 7 - 2020
# 12                    Seabirds Calling at Sea Surface
# 13                     Seabirds Diving at Sea Surface
# 14   Unknown Animal Knock on Hydrophone - "Knockfish"
# 15                   Cruise Ship Underwater Recording
# 16                   State Ferry Hydrophone Recording
# 17                     Freighter Hydrophone Recording
# 18           Small Diesel Engine Hydrophone Recording
# 19             Outboard Engine Whine and Acceleration
# 20                 Outboard Engine (60hp) at 10 Knots
# 21                 Outboard Engine (60hp) at 20 Knots
# 22               Propeller Whine Hydrophone Recording
# 23                          Heavy Rain on Sea Surface
# 24                          Light Rain on Sea Surface
# 25                            Snowfall on Sea Surface
# 26  Light Wind at the Sea Surface - Underwater Rec...
# 27  Moderate Wind on the Sea Surface - Underwater ...
# 28       Wind and Ship Noise on Underwater Hydrophone
#
#                                         download_link
# 0   https://www.nps.gov/nps-audiovideo/audiovideo/...
# 1   https://www.nps.gov/nps-audiovideo/audiovideo/...
# 2   https://www.nps.gov/nps-audiovideo/audiovideo/...
# 3   https://www.nps.gov/nps-audiovideo/audiovideo/...
# 4   https://www.nps.gov/nps-audiovideo/audiovideo/...
# 5   https://www.nps.gov/nps-audiovideo/audiovideo/...
# 6   https://www.nps.gov/nps-audiovideo/audiovideo/...
# 7   https://www.nps.gov/nps-audiovideo/audiovideo/...
# 8   https://www.nps.gov/nps-audiovideo/audiovideo/...
# 9   https://www.nps.gov/nps-audiovideo/audiovideo/...
# 10  https://www.nps.gov/nps-audiovideo/audiovideo/...
# 11  https://www.nps.gov/nps-audiovideo/audiovideo/...
# 12  https://www.nps.gov/nps-audiovideo/audiovideo/...
# 13  https://www.nps.gov/nps-audiovideo/audiovideo/...
# 14  https://www.nps.gov/nps-audiovideo/audiovideo/...
# 15  https://www.nps.gov/nps-audiovideo/audiovideo/...
# 16  https://www.nps.gov/nps-audiovideo/audiovideo/...
# 17  https://www.nps.gov/nps-audiovideo/audiovideo/...
# 18  https://www.nps.gov/nps-audiovideo/audiovideo/...
# 19  https://www.nps.gov/nps-audiovideo/audiovideo/...
# 20  https://www.nps.gov/nps-audiovideo/audiovideo/...
# 21  https://www.nps.gov/nps-audiovideo/audiovideo/...
# 22  https://www.nps.gov/nps-audiovideo/audiovideo/...
# 23  https://www.nps.gov/nps-audiovideo/audiovideo/...
# 24  https://www.nps.gov/nps-audiovideo/audiovideo/...
# 25  https://www.nps.gov/nps-audiovideo/audiovideo/...
# 26  https://www.nps.gov/nps-audiovideo/audiovideo/...
# 27  https://www.nps.gov/nps-audiovideo/audiovideo/...
# 28  https://www.nps.gov/nps-audiovideo/audiovideo/...

# %%
df.to_csv('/content/drive/MyDrive/lewagon-deepdive/working_environment/01.getting_data/scraping Glacier Bay sounds/glacier_bay_sounds.csv',index=False)
