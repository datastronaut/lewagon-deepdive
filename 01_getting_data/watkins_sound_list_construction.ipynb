# %% [markdown]
# ###### Imports

# %%
from google.colab import drive
drive.mount('/content/drive')
project_path = '/content/drive/MyDrive/lewagon-deepdive/'
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
import time
import librosa
import numpy as np
import pandas as pd
import seaborn as sns
from scipy.io import wavfile
import matplotlib.pyplot as plt
from tqdm import tqdm
import soundfile as sf

# using tqdm with pandas
tqdm.pandas(desc="Progress")

# %% [markdown]
# # Dataframe construction

# %% [markdown]
# ## Track list

# %%
sound_list = pd.read_csv('/content/drive/MyDrive/lewagon-deepdive/raw_data/watkins_all_cuts.csv',sep=';')

# %%
sound_list.shape
# Out:
# (15566, 6)

# %%
sound_list.head(2)
# Out:
#   species_code          species_name location observation_date  \
# 0        BD15F  Stenella frontalis        NaN    6-Aug-1961
# 1        BD15F  Stenella frontalis        NaN    6-Aug-1961
#
#                                      download_link  \
# 0  /science/B/whalesounds/WhaleSounds/61025001.wav
# 1  /science/B/whalesounds/WhaleSounds/61025002.wav
#
#                                           metadata
# 0  javascript:popUpWin('metaData.cfm?RN=61025001')
# 1  javascript:popUpWin('metaData.cfm?RN=61025002')

# %% [markdown]
# ## Species list

# %%
df_species = pd.read_csv('/content/drive/MyDrive/lewagon-deepdive/raw_data/species_table.csv',sep=';')

# %%
df_species.shape
# Out:
# (133, 9)

# %%
df_species.head(2)
# Out:
#   order_code order_name family_code family_name genus_code genus_name  \
# 0          A  Mysticeti          AA  Balaenidae        AA1    Balaena
# 1          A  Mysticeti          AA  Balaenidae        AA3  Eubalaena
#
#   species_code                         species_name           common_name
# 0         AA1A     Balaena mysticetus Linnaeus 1758         Bowhead whale
# 1         AA3A  Eubalaena glacialis (Borowski) 1781  Northern right whale

# %% [markdown]
# ## Merge both

# %%
sound_list = pd.merge(
                    sound_list, 
                    df_species, 
                    on ='species_code', 
                    how ='left')

# %%
sound_list.head(2)
# Out:
#   species_code        species_name_x location observation_date  \
# 0        BD15F  Stenella frontalis        NaN    6-Aug-1961
# 1        BD15F  Stenella frontalis        NaN    6-Aug-1961
#
#                                      download_link  \
# 0  /science/B/whalesounds/WhaleSounds/61025001.wav
# 1  /science/B/whalesounds/WhaleSounds/61025002.wav
#
#                                           metadata order_code  order_name  \
# 0  javascript:popUpWin('metaData.cfm?RN=61025001')          B  Odontoceti
# 1  javascript:popUpWin('metaData.cfm?RN=61025002')          B  Odontoceti
#
#   family_code  family_name genus_code genus_name  \
# 0          BD  Delphinidae       BD15   Stenella
# 1          BD  Delphinidae       BD15   Stenella
#
#                         species_name_y               common_name
# 0  Stenella frontalis (G. Cuvier) 1829  Atlantic Spotted Dolphin
# 1  Stenella frontalis (G. Cuvier) 1829  Atlantic Spotted Dolphin

# %% [markdown]
# ## Add a filename column

# %%
sound_list['filename']=sound_list['species_code'] + "_" + sound_list['download_link'].str.rsplit('/',n=1, expand=True)[1]

# %%
sound_list.head(2)
# Out:
#   species_code        species_name_x location observation_date  \
# 0        BD15F  Stenella frontalis        NaN    6-Aug-1961
# 1        BD15F  Stenella frontalis        NaN    6-Aug-1961
#
#                                      download_link  \
# 0  /science/B/whalesounds/WhaleSounds/61025001.wav
# 1  /science/B/whalesounds/WhaleSounds/61025002.wav
#
#                                           metadata order_code  order_name  \
# 0  javascript:popUpWin('metaData.cfm?RN=61025001')          B  Odontoceti
# 1  javascript:popUpWin('metaData.cfm?RN=61025002')          B  Odontoceti
#
#   family_code  family_name genus_code genus_name  \
# 0          BD  Delphinidae       BD15   Stenella
# 1          BD  Delphinidae       BD15   Stenella
#
#                         species_name_y               common_name  \
# 0  Stenella frontalis (G. Cuvier) 1829  Atlantic Spotted Dolphin
# 1  Stenella frontalis (G. Cuvier) 1829  Atlantic Spotted Dolphin
#
#              filename
# 0  BD15F_61025001.wav
# 1  BD15F_61025002.wav

# %% [markdown]
# ## Add a duration column and a sampling rate column

# %% [markdown]
# ### Define a function to get duration and a function for sampling rate

# %%
sf.info('/content/drive/MyDrive/lewagon-deepdive/raw_data/Watkins_all_cuts_part1/BD15F_61025007.wav').__getattribute__('duration')
# Out:
# 1.763986332574032

# %%
def file_duration(filename):
    """ return the duration in seconds of an audio file """
    
    # directory where .wav files are stored
    directory = '/content/drive/MyDrive/lewagon-deepdive/raw_data/Watkins_all_cuts_part2'
    
    path = f'{directory}/{filename}'
    
    # try except to avoid errors due to corrupted files
    try:
        return sf.info(path).__getattribute__('duration')
    except:
        return np.nan

# %%
def file_sampling_rate(filename):
  """ return the sampling rate of a .wav file """
  
  # directory where .wav files are stored
  directory = project_path + 'raw_data/wav_files'
  
  path = f'{directory}/{filename}'
  
  # try except to avoid errors due to corrupted files
  try:
      sampling_rate, data = wavfile.read(path)
      return sampling_rate
  except:
      return np.nan

# %% [markdown]
# ### Apply the functions on entire dataframe
# ❗Attention : next cell takes a long time to compute

# %%
# splitting my df in two parts
sound_list_part1 = sound_list.iloc[:8_114]
sound_list_part2 = sound_list.iloc[8_114:]

# %%
sound_list_part2
# Out:
#       species_code                         species_name_x  \
# 8114          BE3C                 Globicephala melaena
# 8115          BE3C                 Globicephala melaena
# 8116          BE3C                 Globicephala melaena
# 8117          BE3C                 Globicephala melaena
# 8118          BE3C  Globicephala melaena   | Transient  X
# ...            ...                                    ...
# 15561         BD6A                Lagenorhynchus acutus
# 15562         BD6A                Lagenorhynchus acutus
# 15563         BD6A                Lagenorhynchus acutus
# 15564         BD6A                Lagenorhynchus acutus
# 15565         BD6A                Lagenorhynchus acutus
#
#                           location   observation_date  \
# 8114      Western North Atlantic           12-sept-75
# 8115      Western North Atlantic           12-sept-75
# 8116      Western North Atlantic           12-sept-75
# 8117      Western North Atlantic           12-sept-75
# 8118   Western North Atlantic    X  12-Sep-1975    X
# ...                            ...                ...
# 15561       E of Stellwagen Bank       25-Apr-1979
# 15562       E of Stellwagen Bank       25-Apr-1979
# 15563       E of Stellwagen Bank       25-Apr-1979
# 15564       E of Stellwagen Bank       25-Apr-1979
# 15565       E of Stellwagen Bank       25-Apr-1979
#
#                                          download_link  \
# 8114   /science/B/whalesounds/WhaleSounds/7501000M.wav
# 8115   /science/B/whalesounds/WhaleSounds/7501000N.wav
# 8116   /science/B/whalesounds/WhaleSounds/7501000O.wav
# 8117   /science/B/whalesounds/WhaleSounds/7501000P.wav
# 8118   /science/B/whalesounds/WhaleSounds/7501000Q.wav
# ...                                                ...
# 15561  /science/B/whalesounds/WhaleSounds/79006015.wav
# 15562  /science/B/whalesounds/WhaleSounds/79006016.wav
# 15563  /science/B/whalesounds/WhaleSounds/79006017.wav
# 15564  /science/B/whalesounds/WhaleSounds/79006018.wav
# 15565  /science/B/whalesounds/WhaleSounds/79006019.wav
#
#                                               metadata order_code  order_name  \
# 8114   javascript:popUpWin('metaData.cfm?RN=7501000M')          B  Odontoceti
# 8115   javascript:popUpWin('metaData.cfm?RN=7501000N')          B  Odontoceti
# 8116   javascript:popUpWin('metaData.cfm?RN=7501000O')          B  Odontoceti
# 8117   javascript:popUpWin('metaData.cfm?RN=7501000P')          B  Odontoceti
# 8118   javascript:popUpWin('metaData.cfm?RN=7501000Q')          B  Odontoceti
# ...                                                ...        ...         ...
# 15561  javascript:popUpWin('metaData.cfm?RN=79006015')          B  Odontoceti
# 15562  javascript:popUpWin('metaData.cfm?RN=79006016')          B  Odontoceti
# 15563  javascript:popUpWin('metaData.cfm?RN=79006017')          B  Odontoceti
# 15564  javascript:popUpWin('metaData.cfm?RN=79006018')          B  Odontoceti
# 15565  javascript:popUpWin('metaData.cfm?RN=79006019')          B  Odontoceti
#
#       family_code      family_name genus_code      genus_name  \
# 8114           BE  Globicephalidae        BE3    Globicephala
# 8115           BE  Globicephalidae        BE3    Globicephala
# 8116           BE  Globicephalidae        BE3    Globicephala
# 8117           BE  Globicephalidae        BE3    Globicephala
# 8118           BE  Globicephalidae        BE3    Globicephala
# ...           ...              ...        ...             ...
# 15561          BD      Delphinidae        BD6  Lagenorhynchus
# 15562          BD      Delphinidae        BD6  Lagenorhynchus
# 15563          BD      Delphinidae        BD6  Lagenorhynchus
# 15564          BD      Delphinidae        BD6  Lagenorhynchus
# 15565          BD      Delphinidae        BD6  Lagenorhynchus
#
#                            species_name_y          common_name  \
# 8114   Globicephala melaena (Traill) 1809    Long-finned pilot
# 8115   Globicephala melaena (Traill) 1809    Long-finned pilot
# 8116   Globicephala melaena (Traill) 1809    Long-finned pilot
# 8117   Globicephala melaena (Traill) 1809    Long-finned pilot
# 8118   Globicephala melaena (Traill) 1809    Long-finned pilot
# ...                                   ...                  ...
# 15561   Lagenorhynchus acutus (Gray) 1828  White-sided dolphin
# 15562   Lagenorhynchus acutus (Gray) 1828  White-sided dolphin
# 15563   Lagenorhynchus acutus (Gray) 1828  White-sided dolphin
# 15564   Lagenorhynchus acutus (Gray) 1828  White-sided dolphin
# 15565   Lagenorhynchus acutus (Gray) 1828  White-sided dolphin
#
#                 filename
# 8114   BE3C_7501000M.wav
# 8115   BE3C_7501000N.wav
# 8116   BE3C_7501000O.wav
# 8117   BE3C_7501000P.wav
# 8118   BE3C_7501000Q.wav
# ...                  ...
# 15561  BD6A_79006015.wav
# 15562  BD6A_79006016.wav
# 15563  BD6A_79006017.wav
# 15564  BD6A_79006018.wav
# 15565  BD6A_79006019.wav
#
# [7452 rows x 15 columns]

# %%
sound_list_part2['duration'] = sound_list_part2['filename'].progress_apply(lambda x: file_duration(x))
sound_list_part2.to_csv('/content/drive/MyDrive/lewagon-deepdive/raw_data/all_sounds_part2.csv', index=False)
# Out:
# Progress: 100%|██████████| 7452/7452 [28:48<00:00,  4.31it/s]
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
sound_list_part2 = pd.read_csv('/content/drive/MyDrive/lewagon-deepdive/raw_data/all_sounds_part2.csv')

# %%
sound_list_part2.head(2)
# Out:
#   species_code          species_name_x                  location  \
# 0         BE3C  Globicephala melaena    Western North Atlantic
# 1         BE3C  Globicephala melaena    Western North Atlantic
#
#   observation_date                                    download_link  \
# 0       12-sept-75  /science/B/whalesounds/WhaleSounds/7501000M.wav
# 1       12-sept-75  /science/B/whalesounds/WhaleSounds/7501000N.wav
#
#                                           metadata order_code  order_name  \
# 0  javascript:popUpWin('metaData.cfm?RN=7501000M')          B  Odontoceti
# 1  javascript:popUpWin('metaData.cfm?RN=7501000N')          B  Odontoceti
#
#   family_code      family_name genus_code    genus_name  \
# 0          BE  Globicephalidae        BE3  Globicephala
# 1          BE  Globicephalidae        BE3  Globicephala
#
#                        species_name_y        common_name           filename  \
# 0  Globicephala melaena (Traill) 1809  Long-finned pilot  BE3C_7501000M.wav
# 1  Globicephala melaena (Traill) 1809  Long-finned pilot  BE3C_7501000N.wav
#
#    duration
# 0  2.023001
# 1  1.388547

# %%
# counting the number of wrong files
sound_list_part2.duration.isna().sum()
# Out:
# 0

# %% [markdown]
# ## Drop unnecessary rows and columns and reorder columns

# %%
sound_list_part2.shape
# Out:
# (7452, 16)

# %%
# drop rows where duration is nan
# sound_list_part2 = sound_list_part2[sound_list_part2.duration.isna() == False]
# sound_list_part2.shape

# %%
sound_list_part2.columns
# Out:
# Index(['species_code', 'species_name_x', 'location', 'observation_date',
#        'download_link', 'metadata', 'order_code', 'order_name', 'family_code',
#        'family_name', 'genus_code', 'genus_name', 'species_name_y',
#        'common_name', 'filename', 'duration'],
#       dtype='object')

# %%
# dropping columns
sound_list_part2.drop(columns=['order_code', 'order_name', 'genus_code', 'genus_name', 'download_link','metadata','species_name_y'], inplace=True)

# %%
sound_list_part2.columns
# Out:
# Index(['species_code', 'species_name_x', 'location', 'observation_date',
#        'family_code', 'family_name', 'common_name', 'filename', 'duration'],
#       dtype='object')

# %%
# reordering
columns_in_order = ['family_code', 'family_name',
                    'species_code', 'species_name_x', 'common_name',
                    'filename', 'duration',
                    'location', 'observation_date'
                    ]

sound_list_part2 = sound_list_part2[columns_in_order]

# %%
sound_list_part2.head(10)
# Out:
#   family_code      family_name species_code  \
# 0          BE  Globicephalidae         BE3C
# 1          BE  Globicephalidae         BE3C
# 2          BE  Globicephalidae         BE3C
# 3          BE  Globicephalidae         BE3C
# 4          BE  Globicephalidae         BE3C
# 5          BE  Globicephalidae         BE3C
# 6          BE  Globicephalidae         BE3C
# 7          BE  Globicephalidae         BE3C
# 8          BE  Globicephalidae         BE3C
# 9          BE  Globicephalidae         BE3C
#
#                           species_name_x        common_name  \
# 0                 Globicephala melaena    Long-finned pilot
# 1                 Globicephala melaena    Long-finned pilot
# 2                 Globicephala melaena    Long-finned pilot
# 3                 Globicephala melaena    Long-finned pilot
# 4  Globicephala melaena   | Transient  X  Long-finned pilot
# 5                 Globicephala melaena    Long-finned pilot
# 6                 Globicephala melaena    Long-finned pilot
# 7                 Globicephala melaena    Long-finned pilot
# 8  Globicephala melaena   | Transient  X  Long-finned pilot
# 9                 Globicephala melaena    Long-finned pilot
#
#             filename  duration                     location   observation_date
# 0  BE3C_7501000M.wav  2.023001     Western North Atlantic           12-sept-75
# 1  BE3C_7501000N.wav  1.388547     Western North Atlantic           12-sept-75
# 2  BE3C_7501000O.wav  1.435678     Western North Atlantic           12-sept-75
# 3  BE3C_7501000P.wav  1.098511     Western North Atlantic           12-sept-75
# 4  BE3C_7501000Q.wav  1.696711  Western North Atlantic    X  12-Sep-1975    X
# 5  BE3C_7501000R.wav  1.794598     Western North Atlantic           12-sept-75
# 6  BE3C_7501000S.wav  1.450180     Western North Atlantic           12-sept-75
# 7  BE3C_7501000T.wav  2.320288     Western North Atlantic           12-sept-75
# 8  BE3C_7501000U.wav  2.099136  Western North Atlantic    X  12-Sep-1975    X
# 9  BE3C_7501000V.wav  1.819976     Western North Atlantic           12-sept-75

# %% [markdown]
# ## Replacing all ',' by ' -' in order not to mess up with csv conversion

# %%
sound_list_part2.replace(',', ' -', inplace=True, regex=True)

# %%
#renaming columns
sound_list_part2.rename(columns={"species_name_x": "species_name"}, inplace=True)

# %%
sound_list_part2
# Out:
#      family_code      family_name species_code  \
# 0             BE  Globicephalidae         BE3C
# 1             BE  Globicephalidae         BE3C
# 2             BE  Globicephalidae         BE3C
# 3             BE  Globicephalidae         BE3C
# 4             BE  Globicephalidae         BE3C
# ...          ...              ...          ...
# 7447          BD      Delphinidae         BD6A
# 7448          BD      Delphinidae         BD6A
# 7449          BD      Delphinidae         BD6A
# 7450          BD      Delphinidae         BD6A
# 7451          BD      Delphinidae         BD6A
#
#                                species_name          common_name  \
# 0                    Globicephala melaena      Long-finned pilot
# 1                    Globicephala melaena      Long-finned pilot
# 2                    Globicephala melaena      Long-finned pilot
# 3                    Globicephala melaena      Long-finned pilot
# 4     Globicephala melaena   | Transient  X    Long-finned pilot
# ...                                     ...                  ...
# 7447                Lagenorhynchus acutus    White-sided dolphin
# 7448                Lagenorhynchus acutus    White-sided dolphin
# 7449                Lagenorhynchus acutus    White-sided dolphin
# 7450                Lagenorhynchus acutus    White-sided dolphin
# 7451                Lagenorhynchus acutus    White-sided dolphin
#
#                filename  duration                     location  \
# 0     BE3C_7501000M.wav  2.023001     Western North Atlantic
# 1     BE3C_7501000N.wav  1.388547     Western North Atlantic
# 2     BE3C_7501000O.wav  1.435678     Western North Atlantic
# 3     BE3C_7501000P.wav  1.098511     Western North Atlantic
# 4     BE3C_7501000Q.wav  1.696711  Western North Atlantic    X
# ...                 ...       ...                          ...
# 7447  BD6A_79006015.wav  1.011072       E of Stellwagen Bank
# 7448  BD6A_79006016.wav  1.490625       E of Stellwagen Bank
# 7449  BD6A_79006017.wav  0.889673       E of Stellwagen Bank
# 7450  BD6A_79006018.wav  0.730884       E of Stellwagen Bank
# 7451  BD6A_79006019.wav  0.775269       E of Stellwagen Bank
#
#        observation_date
# 0            12-sept-75
# 1            12-sept-75
# 2            12-sept-75
# 3            12-sept-75
# 4     12-Sep-1975    X
# ...                 ...
# 7447     25-Apr-1979
# 7448     25-Apr-1979
# 7449     25-Apr-1979
# 7450     25-Apr-1979
# 7451     25-Apr-1979
#
# [7452 rows x 9 columns]

# %% [markdown]
# ## Identifying rows with several species

# %%
# TODO : remove species codes from location and date columns and add a column with multi-species T/F and a columns by additional species

# %% [markdown]
# ## Identifying rows with noise

# %%
# TODO : remove noise code from location and date columns and add a column with noise T/F and a columns by noise type

# %% [markdown]
# ## Final tracklist

# %%
sound_list_part2.to_csv('/content/drive/MyDrive/lewagon-deepdive/raw_data/all_sounds_part2.csv', index=False)

# %%
time.strftime('%H:%M:%S', time.gmtime(sound_list_part2.duration.sum()))
# Out:
# '17:43:47'

# %%
sound_list_part1 = pd.read_csv('/content/drive/MyDrive/lewagon-deepdive/raw_data/all_sounds_part1.csv')

# %%
sound_list_part1.head(2)
# Out:
#   family_code  family_name species_code        species_name_x  \
# 0          BD  Delphinidae        BD15F  Stenella frontalis
# 1          BD  Delphinidae        BD15F  Stenella frontalis
#
#                 common_name            filename  duration location  \
# 0  Atlantic Spotted Dolphin  BD15F_61025001.wav  3.527995      NaN
# 1  Atlantic Spotted Dolphin  BD15F_61025002.wav  3.527995      NaN
#
#   observation_date
# 0    6-Aug-1961
# 1    6-Aug-1961

# %%
#renaming columns
sound_list_part1.rename(columns={"species_name_x": "species_name"}, inplace=True)

# %%
sound_list_part1.head(2)
# Out:
#   family_code  family_name species_code          species_name  \
# 0          BD  Delphinidae        BD15F  Stenella frontalis
# 1          BD  Delphinidae        BD15F  Stenella frontalis
#
#                 common_name            filename  duration location  \
# 0  Atlantic Spotted Dolphin  BD15F_61025001.wav  3.527995      NaN
# 1  Atlantic Spotted Dolphin  BD15F_61025002.wav  3.527995      NaN
#
#   observation_date
# 0    6-Aug-1961
# 1    6-Aug-1961

# %%
sound_list_part2.head(2)
# Out:
#   family_code      family_name species_code            species_name  \
# 0          BE  Globicephalidae         BE3C  Globicephala melaena
# 1          BE  Globicephalidae         BE3C  Globicephala melaena
#
#          common_name           filename  duration                  location  \
# 0  Long-finned pilot  BE3C_7501000M.wav  2.023001  Western North Atlantic
# 1  Long-finned pilot  BE3C_7501000N.wav  1.388547  Western North Atlantic
#
#   observation_date
# 0       12-sept-75
# 1       12-sept-75

# %%
total_sound_list = pd.concat([sound_list_part1,sound_list_part2], ignore_index=True)

# %%
total_sound_list
# Out:
#       family_code  family_name species_code             species_name  \
# 0              BD  Delphinidae        BD15F     Stenella frontalis
# 1              BD  Delphinidae        BD15F     Stenella frontalis
# 2              BD  Delphinidae        BD15F     Stenella frontalis
# 3              BD  Delphinidae        BD15F     Stenella frontalis
# 4              BD  Delphinidae        BD15F     Stenella frontalis
# ...           ...          ...          ...                      ...
# 15560          BD  Delphinidae         BD6A  Lagenorhynchus acutus
# 15561          BD  Delphinidae         BD6A  Lagenorhynchus acutus
# 15562          BD  Delphinidae         BD6A  Lagenorhynchus acutus
# 15563          BD  Delphinidae         BD6A  Lagenorhynchus acutus
# 15564          BD  Delphinidae         BD6A  Lagenorhynchus acutus
#
#                     common_name            filename  duration  \
# 0      Atlantic Spotted Dolphin  BD15F_61025001.wav  3.527995
# 1      Atlantic Spotted Dolphin  BD15F_61025002.wav  3.527995
# 2      Atlantic Spotted Dolphin  BD15F_61025003.wav  3.527995
# 3      Atlantic Spotted Dolphin  BD15F_61025004.wav  1.763986
# 4      Atlantic Spotted Dolphin  BD15F_61025005.wav  1.323007
# ...                         ...                 ...       ...
# 15560       White-sided dolphin   BD6A_79006015.wav  1.011072
# 15561       White-sided dolphin   BD6A_79006016.wav  1.490625
# 15562       White-sided dolphin   BD6A_79006017.wav  0.889673
# 15563       White-sided dolphin   BD6A_79006018.wav  0.730884
# 15564       White-sided dolphin   BD6A_79006019.wav  0.775269
#
#                      location observation_date
# 0                         NaN    6-Aug-1961
# 1                         NaN    6-Aug-1961
# 2                         NaN    6-Aug-1961
# 3                         NaN    6-Aug-1961
# 4                         NaN    6-Aug-1961
# ...                       ...              ...
# 15560  E of Stellwagen Bank     25-Apr-1979
# 15561  E of Stellwagen Bank     25-Apr-1979
# 15562  E of Stellwagen Bank     25-Apr-1979
# 15563  E of Stellwagen Bank     25-Apr-1979
# 15564  E of Stellwagen Bank     25-Apr-1979
#
# [15565 rows x 9 columns]

# %%
# total_sound_list.to_csv('/content/drive/MyDrive/lewagon-deepdive/raw_data/watkins_sound_list_extended.csv',index=False)

# %%
check = pd.read_csv('/content/drive/MyDrive/lewagon-deepdive/raw_data/watkins_sound_list_extended.csv')

# %%
check
# Out:
#       family_code  family_name species_code           species_name  \
# 0              BD  Delphinidae        BD15F     Stenella frontalis
# 1              BD  Delphinidae        BD15F     Stenella frontalis
# 2              BD  Delphinidae        BD15F     Stenella frontalis
# 3              BD  Delphinidae        BD15F     Stenella frontalis
# 4              BD  Delphinidae        BD15F     Stenella frontalis
# ...           ...          ...          ...                    ...
# 15560          BD  Delphinidae         BD6A  Lagenorhynchus acutus
# 15561          BD  Delphinidae         BD6A  Lagenorhynchus acutus
# 15562          BD  Delphinidae         BD6A  Lagenorhynchus acutus
# 15563          BD  Delphinidae         BD6A  Lagenorhynchus acutus
# 15564          BD  Delphinidae         BD6A  Lagenorhynchus acutus
#
#                     common_name            filename  duration  \
# 0      Atlantic Spotted Dolphin  BD15F_61025001.wav  3.527995
# 1      Atlantic Spotted Dolphin  BD15F_61025002.wav  3.527995
# 2      Atlantic Spotted Dolphin  BD15F_61025003.wav  3.527995
# 3      Atlantic Spotted Dolphin  BD15F_61025004.wav  1.763986
# 4      Atlantic Spotted Dolphin  BD15F_61025005.wav  1.323007
# ...                         ...                 ...       ...
# 15560       White-sided dolphin   BD6A_79006015.wav  1.011072
# 15561       White-sided dolphin   BD6A_79006016.wav  1.490625
# 15562       White-sided dolphin   BD6A_79006017.wav  0.889673
# 15563       White-sided dolphin   BD6A_79006018.wav  0.730884
# 15564       White-sided dolphin   BD6A_79006019.wav  0.775269
#
#                    location observation_date  noise  multi_species
# 0                       NaN       6-Aug-1961  False          False
# 1                       NaN       6-Aug-1961  False          False
# 2                       NaN       6-Aug-1961  False          False
# 3                       NaN       6-Aug-1961  False          False
# 4                       NaN       6-Aug-1961  False          False
# ...                     ...              ...    ...            ...
# 15560  E of Stellwagen Bank      25-Apr-1979  False          False
# 15561  E of Stellwagen Bank      25-Apr-1979  False          False
# 15562  E of Stellwagen Bank      25-Apr-1979  False          False
# 15563  E of Stellwagen Bank      25-Apr-1979  False          False
# 15564  E of Stellwagen Bank      25-Apr-1979  False          False
#
# [15565 rows x 11 columns]
